# %%
import pandas as pd

# %%
def clean_data_load():
    try :
        df = pd.read_csv("data/processed_dataset.csv")
        return df
    except FileNotFoundError :
        print("Please make sure that you have file in the given path")
        return None
    except Exception as e :
        print(f"Error {str(e)}")
        return None
df = clean_data_load()

# %%
df.head()
# Out:
#    cpu_usage  memory_usage  disk_usage  hour  minute  is_weekend  \
# 0        4.9          28.3        39.5    15      50       False
# 1        3.0          28.5        39.5    15      51       False
# 2        5.8          28.4        39.5    15      52       False
# 3       30.7          30.3        39.5    15      53       False
# 4        5.8          27.7        39.5    15      54       False
#
#    cpu_roll_mean_5  cpu_roll_std_5  cpu_roll_30min
# 0              NaN             NaN        4.900000
# 1              NaN             NaN        3.950000
# 2              NaN             NaN        4.566667
# 3              NaN             NaN       11.100000
# 4            10.04       11.605731       10.040000
